# %% [markdown]
# ## <font color='blue'>作業一<font>
# ### <font color=#000075>資料 : TMDB Box Office Prediction<font>
# <font color=#000075>這組資料提供美國地區1916年到2017年共7398部電影的相關資訊，包含卡司、劇情、預算、上映日期、製片公司等，希望能夠預測電影上映後的票房收入有多少。 <font>
#
# 1. __你選的這組資料為何重要<br>__
# 透過預測一部電影的賣座程度，製片公司、投資人、戲院能夠事先評估拍一部電影或是上映一部電影獲利情況。<br><br>
#
# 2. __資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)__<br>
# 資料來自The Movie DB。<br><br>
#
# 3. __蒐集而來的資料型態為何__<br>
# 結構化資料，key值為電影的id。<br><br>
#
# 4. __這組資料想解決的問題如何評估__<br>
# 欲預測票房收入可以使用RMSLE來評估。<br><br>
#
# ## <font color=#000075>作業二<font>
#
# <font color=#000075>想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：<font>
#
# 1. __核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)__<br>
# 假設車隊在上下班時間的客源穩定，要增加業績則可以針對上午10點~下午4點這段期間的客源安排。<br><br>
#
# 2. __資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)__
# 透過爬網收集臉書上公開活動的消息，或是百貨公司的行銷活動等，分析每天有哪些時段和地方會有較多的人聚集，也就有機會是客源。<br><br>
#
# 3. __蒐集而來的資料型態為何__<br>
# 結構化資料，包含日期、地點、活動型態、參與人數等欄位。<br><br>
#
# 4. __你要回答的問題，其如何評估 (tips：你的假設如何驗證)__<br>
# 做短期實驗，比如實行兩周到一個月，計算每日、當月的營收，並針對想優化的時段做統計與分析檢定，來決定這個策略是否有短期見效，抑或需要拉長評估的時間。最終看的是日營收與月營收是否有顯著上升。<br><br>

# %% [markdown]
# ## <font color=#000075>作業三<font>
# <font color=#000075>請寫一個函式用來計算 Mean Square Error<font>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %% [markdown]
# ## <font color=#000075>mean absolute error<font>

# %%
def mean_absolute_error(y, yp):
    mae = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.967

# %% [markdown]
# ## <font color=#000075>mean square error<font>

# %% [markdown]
# def mean_square_error(y, yp):
#     mse = sum((y - yp)**2) / len(y)
#     return mse
#
# MSE = mean_square_error(y, y_hat)
# print("The Mean absolute error is %.3f" % (MSE))
